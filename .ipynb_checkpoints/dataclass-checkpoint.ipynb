# %% [markdown]
# # 날짜 데이터 클래스
# ## python 기본 라이브러리 : date, datetime
#
# ## pandas : Timestamp
#
# ## numpy : datetime64

# %%
import pandas as pdts
import numpy as np
import datetime as dt

# %% [markdown]
# # 날짜 데이터 생성
# ## datetime - date() 또는 datetime()
# python의 기본 날짜 라이브러리인 datetime는 클래스 생성자를 통해 pandas와 유사하게 날짜와 시간을 정의할 수 있습니다. pandas와 다른 점은 Timestamp는 날짜와 시간이 통합되어 있는데 반해, datetime 라이브러리는 날짜만 담고 있는 date, 시간만 담고 있는 time, 날짜-시간을 모두 담고 있는 datetime 클래스가 구분되어 있어 용도에 따라 구분하여 사용합니다.

# %%
py_date1 = dt.date(2023, 2, 4)
py_date2 = dt.datetime(2023, 2, 4)

# %%
print(py_date1)
print(py_date2)
# Out:
# 2023-02-04
# 2023-02-04 00:00:00

# %%
py_date1 == py_date2
# Out:
# False

# %% [markdown]
# ## pandas - Timestamp()
# 날짜 형식을 정의하는 가장 기본적인 방법으로 연도, 월, 일, 시, 분, 초 등 날짜와 시간의 각 구성요소를 숫자로 입력하는 방법이 있습니다. pandas에서는 Timestamp() 함수로 날짜와 시간을 정의할 수 있으며, 매개변수는 맨 앞은 연도, 그 다음 부터는 월, 일, 시, 분, 초 순서로 입력됩니다. 또는 각 매개변수명을 'year=2020'와 같이 명시적으로 표시해서 정의도 가능합니다.

# %%
pd_date1 = pdts.Timestamp('2023-02-04')
pd_date2 = pdts.Timestamp(2023, 2, 4)
pd_date3 = pdts.to_datetime(19392, unit = 'd') ## 1970년 1월 1일로부터의 경과일수
# Out:
# Timestamp('2023-02-04 00:00:00')

# %%
pd_date1 == pd_date2 == pd_date3
# Out:
# True

# %%
print(type(pd_date1))
# Out:
# <class 'pandas._libs.tslibs.timestamps.Timestamp'>

# %%
# Out:
# DatetimeIndex(['2023-02-04', '2023-02-05'], dtype='datetime64[ns]', freq=None)

# %% [markdown]
# ## numpy - 없음
# numpy의 datetime64 타입은 위와 같이 숫자 형태로 날짜를 정의하는 기능을 제공하고 있지 않습니다. 숫자형태로 넣으면 TypeError가 발생합니다.

# %%
np_date = np.datetime64('2023-02-04')
print(np_date)
# Out:
# 2023-02-04

# %%
py_date1 == np_date
# Out:
# True

# %%
print(type(date_index))
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %% [markdown]
# # dateindex

# %%
date_index = pd.to_datetime(['2023-02-04', '2023-02-05'])
date_index
# Out:
# DatetimeIndex(['2023-02-04', '2023-02-05'], dtype='datetime64[ns]', freq=None)

# %%
pd.DatetimeIndex(['2023-02-04', '2023-02-05'])
# Out:
# DatetimeIndex(['2023-02-04', '2023-02-05'], dtype='datetime64[ns]', freq=None)

# %%
pd.date_range("2023-02-04", "2023-03-04")
# Out:
# DatetimeIndex(['2023-02-04', '2023-02-05', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-11',
#                '2023-02-12', '2023-02-13', '2023-02-14', '2023-02-15',
#                '2023-02-16', '2023-02-17', '2023-02-18', '2023-02-19',
#                '2023-02-20', '2023-02-21', '2023-02-22', '2023-02-23',
#                '2023-02-24', '2023-02-25', '2023-02-26', '2023-02-27',
#                '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03',
#                '2023-03-04'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start="2023-02-04", periods=30)
# Out:
# DatetimeIndex(['2023-02-04', '2023-02-05', '2023-02-06', '2023-02-07',
#                '2023-02-08', '2023-02-09', '2023-02-10', '2023-02-11',
#                '2023-02-12', '2023-02-13', '2023-02-14', '2023-02-15',
#                '2023-02-16', '2023-02-17', '2023-02-18', '2023-02-19',
#                '2023-02-20', '2023-02-21', '2023-02-22', '2023-02-23',
#                '2023-02-24', '2023-02-25', '2023-02-26', '2023-02-27',
#                '2023-02-28', '2023-03-01', '2023-03-02', '2023-03-03',
#                '2023-03-04', '2023-03-05'],
#               dtype='datetime64[ns]', freq='D')
